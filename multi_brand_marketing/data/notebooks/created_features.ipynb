# %%
import pandas as pd
from pathlib import Path


# Ler arquivos
df = pd.read_csv('/home/felipe/Projeto/Portfolio/Portfolio2/multi_brand_marketing/data/processed/unified_campaign_data.csv')
df
# Out:
#          Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0        NY-CMP-1000  Social Media       College Students        21
# 1        NY-CMP-1001      Paid Ads  Tier 2 City Customers        18
# 2        NY-CMP-1002    Influencer                  Youth        23
# 3        NY-CMP-1003         Email          Working Women        18
# 4        NY-CMP-1004      Paid Ads       College Students        10
# ...              ...           ...                    ...       ...
# 166660  TI-CMP-56550    Influencer  Tier 2 City Customers        11
# 166661  TI-CMP-56551           SEO          Working Women        20
# 166662  TI-CMP-56552         Email  Tier 2 City Customers        13
# 166663  TI-CMP-56553    Influencer       Premium Shoppers        22
# 166664  TI-CMP-56554      Paid Ads          Working Women         9
#
#                         Channel_Used  Impressions  Clicks  Leads  Conversions  \
# ...

# %%
df.columns
# Out:
# Index(['Campaign_ID', 'Campaign_Type', 'Target_Audience', 'Duration',
#        'Channel_Used', 'Impressions', 'Clicks', 'Leads', 'Conversions',
#        'Revenue', 'Acquisition_Cost', 'ROI', 'Language', 'Engagement_Score',
#        'Customer_Segment', 'Date', 'Brand'],
#       dtype='object')

# %%
import numpy as np

df["CTR"] = np.where(df["Impressions"] > 0, df["Clicks"] / df["Impressions"], 0) 

df["conversion_rate"] = np.where(df["Clicks"] > 0, df["Conversions"] / df["Clicks"], 0) 

df["CPC"] = np.where(df["Clicks"] > 0, df["Acquisition_Cost"] / df["Clicks"], 0)

df["CPA"] = np.where(df["Conversions"] > 0, df["Acquisition_Cost"] / df["Conversions"], 0)

# %%
df
# Out:
#          Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0        NY-CMP-1000  Social Media       College Students        21
# 1        NY-CMP-1001      Paid Ads  Tier 2 City Customers        18
# 2        NY-CMP-1002    Influencer                  Youth        23
# 3        NY-CMP-1003         Email          Working Women        18
# 4        NY-CMP-1004      Paid Ads       College Students        10
# ...              ...           ...                    ...       ...
# 166660  TI-CMP-56550    Influencer  Tier 2 City Customers        11
# 166661  TI-CMP-56551           SEO          Working Women        20
# 166662  TI-CMP-56552         Email  Tier 2 City Customers        13
# 166663  TI-CMP-56553    Influencer       Premium Shoppers        22
# 166664  TI-CMP-56554      Paid Ads          Working Women         9
#
#                         Channel_Used  Impressions  Clicks  Leads  Conversions  \
# ...

# %%
df["ROAS"] = np.where(df["Acquisition_Cost"] > 0, df["Revenue"] / df["Acquisition_Cost"], 0)

df["Revenue_per_click"] = np.where(df["Clicks"] > 0, df["Revenue"] / df["Clicks"], 0)

df["Revenue_per_conversion"] = np.where(df["Conversions"] > 0, df["Revenue"] / df["Conversions"], 0)

# %%
import os

output_path = os.path.join(processed_dir, 'df_complete.csv')
df.to_csv(output_path, index=False)

# %%
df["conversion_rate"].mean()
# Out:
# np.float64(0.21945369723635363)

# %%
df
# Out:
#          Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0        NY-CMP-1000  Social Media       College Students        21
# 1        NY-CMP-1001      Paid Ads  Tier 2 City Customers        18
# 2        NY-CMP-1002    Influencer                  Youth        23
# 3        NY-CMP-1003         Email          Working Women        18
# 4        NY-CMP-1004      Paid Ads       College Students        10
# ...              ...           ...                    ...       ...
# 166660  TI-CMP-56550    Influencer  Tier 2 City Customers        11
# 166661  TI-CMP-56551           SEO          Working Women        20
# 166662  TI-CMP-56552         Email  Tier 2 City Customers        13
# 166663  TI-CMP-56553    Influencer       Premium Shoppers        22
# 166664  TI-CMP-56554      Paid Ads          Working Women         9
#
#                         Channel_Used  Impressions  Clicks  Leads  Conversions  \
# ...

# %%
df['Acquisition_Cost'].sum()
# Out:
# np.float64(62681853.33)
